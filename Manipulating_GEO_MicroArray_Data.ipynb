# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import pyreadr

# %%
# Read in the series Matrix File (Before you do, make sure to open the file in text edit and delete everything before !Sample_title)
sample_info = pd.read_csv("/Volumes/Research_Data/Research_Datasets/Atherosclerosis_Tissue/Atherosclerosis_Whole_Blood_Stroke_450K/Matrix_Truncated.txt",sep='\t',index_col = 0)
sample_info = sample_info.transpose()
sample_info.iloc[:]
# Out:
# !Sample_title                            !Sample_geo_accession  \
# genomic DNA from blood 9403904025_R01C01            GSM1693270
# genomic DNA from blood 9403904025_R01C02            GSM1693271
# genomic DNA from blood 9403904025_R02C01            GSM1693272
# genomic DNA from blood 9403904025_R02C02            GSM1693273
# genomic DNA from blood 9403904025_R03C01            GSM1693274
# ...                                                        ...
# genomic DNA from blood 9980102107_R04C01            GSM3026793
# genomic DNA from blood 9980102107_R04C02            GSM3026794
# genomic DNA from blood 9980102107_R05C01            GSM3026795
# genomic DNA from blood 9980102107_R05C02            GSM3026796
# genomic DNA from blood 9980102107_R06C02            GSM3026797
#
# !Sample_title                                    !Sample_status  \
# genomic DNA from blood 9403904025_R01C01  Public on Aug 19 2015
# genomic DNA from blood 9403904025_R01C02  Public on Aug 19 2015
# ...

# %%
# Sometimes they will add the Processed Beta values, you can seperate those out here so that you have seperate data frames.
# One will be the sample_info and the other your beta_values
sample_info_2 = sample_info.iloc[:,:45]
sample_info_2.iloc[:]
# Out:
# !Sample_title                            !Sample_geo_accession  \
# genomic DNA from blood 9403904025_R01C01            GSM1693270
# genomic DNA from blood 9403904025_R01C02            GSM1693271
# genomic DNA from blood 9403904025_R02C01            GSM1693272
# genomic DNA from blood 9403904025_R02C02            GSM1693273
# genomic DNA from blood 9403904025_R03C01            GSM1693274
# ...                                                        ...
# genomic DNA from blood 9980102107_R04C01            GSM3026793
# genomic DNA from blood 9980102107_R04C02            GSM3026794
# genomic DNA from blood 9980102107_R05C01            GSM3026795
# genomic DNA from blood 9980102107_R05C02            GSM3026796
# genomic DNA from blood 9980102107_R06C02            GSM3026797
#
# !Sample_title                                    !Sample_status  \
# genomic DNA from blood 9403904025_R01C01  Public on Aug 19 2015
# genomic DNA from blood 9403904025_R01C02  Public on Aug 19 2015
# ...

# %%
betas = sample_info.iloc[:,35:-1]
betas.index = sample_info_2["ID_REF"]
# del betas["!series_matrix_table_end"]
# del betas["ID_REF"]
betas = betas.transpose()
betas.iloc[:]
# Out:
# ID_REF          GSM2861662   GSM2861663   GSM2861664   GSM2861665  \
# !Sample_title
# cg00000029      0.51528219   0.57792346  0.505046372  0.414088465
# cg00000108     0.980377624  0.982159319   0.98276171  0.984242217
# cg00000109     0.934728425  0.964230634  0.955782552   0.91088874
# cg00000165     0.260085024   0.25330116  0.182692641  0.113638395
# cg00000236     0.770354559  0.853711317   0.82702188  0.856568983
# ...                    ...          ...          ...          ...
# cg27665860        0.909179     0.829519     0.907301     0.880201
# cg27665925         0.03885     0.046477     0.046256     0.030581
# cg27665985         0.19084     0.297591     0.215958     0.193648
# cg27666046        0.663378     0.449868     0.603512     0.623265
# cg27666123        0.922804      0.87759     0.927514     0.941324
#
# ID_REF          GSM2861666   GSM2861667   GSM2861668   GSM2861669  \
# !Sample_title
# cg00000029     0.589615197  0.344908371  0.488042323  0.551901323
# ...

# %%
# Write the results to a .csv file
sample_info_2.to_csv("/Volumes/Research_Data/Research_Datasets/Atherosclerosis_Tissue/Atherosclerosis_Whole_Blood_Stroke_450K/sample_sheet.csv")

# %%
betas.to_csv("/Volumes/Research_Data/Research_Datasets/Atherosclerosis_Tissue/Atherosclerotic_Whole_Blood_450K/betas.csv")

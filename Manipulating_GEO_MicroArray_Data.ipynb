# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import pyreadr

# %%
# Read in the series Matrix File (Before you do, make sure to open the file in text edit and delete everything before !Sample_title)
sample_info = pd.read_csv("/Volumes/Research_Data/Research_Datasets/Whole_Blood/Whole_Blood_Depression_Study/GSE201287_series_matrix.txt",sep='\t',index_col = 0)
sample_info = sample_info.transpose()
sample_info.iloc[:]
# Out:
# !Sample_title                        !Sample_geo_accession  \
# Blood-major depressive disorder-rep1            GSM6057811
# Blood-major depressive disorder-rep2            GSM6057812
# Blood-major depressive disorder-rep3            GSM6057813
# Blood-major depressive disorder-rep4            GSM6057814
# Blood-major depressive disorder-rep5            GSM6057815
# ...                                                    ...
# Blood-healthy-rep36                             GSM6057886
# Blood-healthy-rep37                             GSM6057887
# Blood-healthy-rep38                             GSM6057888
# Blood-healthy-rep39                             GSM6057889
# Blood-healthy-rep40                             GSM6057890
#
# !Sample_title                                !Sample_status  \
# Blood-major depressive disorder-rep1  Public on Jul 18 2022
# Blood-major depressive disorder-rep2  Public on Jul 18 2022
# Blood-major depressive disorder-rep3  Public on Jul 18 2022
# ...

# %%
# Sometimes they will add the Processed Beta values, you can seperate those out here so that you have seperate data frames.
# One will be the sample_info and the other your beta_values
sample_info_2 = sample_info.iloc[:,:36]
sample_info_2.iloc[:]
# Out:
# !Sample_title              !Sample_geo_accession         !Sample_status  \
# Genomic DNA from blood 1              GSM4299202  Public on Nov 18 2020
# Genomic DNA from blood 2              GSM4299203  Public on Nov 18 2020
# Genomic DNA from blood 3              GSM4299204  Public on Nov 18 2020
# Genomic DNA from blood 4              GSM4299205  Public on Nov 18 2020
# Genomic DNA from blood 5              GSM4299206  Public on Nov 18 2020
# ...                                          ...                    ...
# Genomic DNA from blood 296            GSM4299660  Public on Nov 18 2020
# Genomic DNA from blood 297            GSM4299661  Public on Nov 18 2020
# Genomic DNA from blood 298            GSM4299662  Public on Nov 18 2020
# Genomic DNA from blood 299            GSM4299663  Public on Nov 18 2020
# Genomic DNA from blood 300            GSM4299664  Public on Nov 18 2020
#
# !Sample_title              !Sample_submission_date !Sample_last_update_date  \
# ...

# %%
betas = sample_info.iloc[:,36:-1]
betas.index = sample_info_2["ID_REF"]
# del betas["!series_matrix_table_end"]
# del betas["ID_REF"]
betas = betas.transpose()
betas.iloc[:]
# Out:
# ID_REF                 GSM4299202         GSM4299203         GSM4299204  \
# !Sample_title
# cg00000029      0.610079896085268   0.46177411191613  0.532800775940088
# cg00000108      0.892013471753672  0.874570782964385  0.864435119560279
# cg00000109      0.679462064112195  0.743489171767095  0.750426409698662
# cg00000165      0.380887731157968  0.315226294418013   0.40892972831863
# cg00000236       0.74609185256867  0.692648359661292  0.703012685789263
# ...                           ...                ...                ...
# ch.X.938089F             0.113149           0.146336           0.121263
# ch.X.94051109R           0.089409           0.127122           0.097196
# ch.X.97129969R            0.19375           0.231571           0.220558
# ch.X.97651759F           0.080471           0.092285            0.10204
# ch.X.98007042R           0.179957           0.236591           0.189094
#
# ID_REF                 GSM4299205         GSM4299206         GSM4299207  \
# ...

# %%
# Write the results to a .csv file
sample_info.to_csv("/Volumes/Research_Data/Research_Datasets/Whole_Blood/Whole_Blood_Depression_Study/sample_sheet.csv")

# %%
betas.to_csv("/Volumes/Research_Data/Research_Datasets/Whole_Blood/Alzheimers_Whole_Blood_450K/betas.csv")
